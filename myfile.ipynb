# %%
import pandas as pd
from todoist.api import TodoistAPI
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np 
from pandas_datareader import data
from alpha_vantage.timeseries import TimeSeries

import os, sys
os.system('pip3 install alpha-vantage')
# Out:
# 0

# %%
# todoist api token key
api = TodoistAPI('df864d9cbf7b4e669e50bf626fa088eef855ff5e')
api.sync()

# alpha-vantage api token key
ts = TimeSeries(key='VH08YTEBXJRW8I5C', output_format='pandas')
data, meta_data = TimeSeries(key='VH08YTEBXJRW8I5C', output_format='pandas').get_intraday(symbol='MSFT',interval='1min', outputsize='full')
# data['close'].plot()
plt.title('Intraday Times Series for the MSFT stock (1 min)')
plt.show()

# %%
projects = [project.data for project in api.state['projects']]
df_projects = pd.DataFrame(projects)

# %%
tasks = [task.data for task in api.state['items']]
df_tasks = pd.DataFrame(tasks)

# %%
df_tasks1 = df_tasks[['content', 'due']]

# %%
# stocks
